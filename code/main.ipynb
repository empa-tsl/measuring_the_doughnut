# %% [markdown]
# **Implementation file**

# %% [markdown]
# Running this file will determine the share of safe operating space (SoSOS) in a suffiency case, the share of production (SoP) on a suffiency level, the unit impacts (UI) of every resource in the SoP and carries out a Monte-Carlo-Simulation of the impacts generated by suffiency (the "DLS baskets").

# %%
# %reset

import function_list as func
import importlib
importlib.reload(func) #update imported functions

def main():
    mode='test' #if test run: "test", otherwise any other string
    overwrite=True
    
    #func.setup(mode)
    
    func.calculate_all_SoSOS(mode, overwrite)
    func.calculate_all_MC(mode,10)
    return
if __name__=='__main__':
    main()
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y
# ---------------------------------------------
# Calculating SoSOS for: dls_basket_basic.
# ---------------------------------------------
# ...
#
# Progress: [------------------------------------------------->] 100%
#
# Collected all primary flows up to level 5
# Brightway2 SQLiteBackend: ecoinvent 3.8 cutoff
#
# SoSOS saved at directory:
#  H:\Schlesier_et_al2022\Github\code\SoSOS\SoSOS_data_dls_basket_basic.xlsx
# Calculation of SoSOS for dls_basket_basic completed!
# Performing Monte-Carlo-Simulation for dls_basket_basic
# Finished Monte-Carlo-Simulation for dls_basket_basic
# Monte-Carlo-Simulations completed!
